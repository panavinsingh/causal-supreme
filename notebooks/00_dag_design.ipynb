# %% [markdown]
# # DAG Design Exploration
#
# This notebook explores DAG generation parameters and their effects on dataset properties.

# %%
import sys
sys.path.insert(0, '..')

from src.generator.dag_factory import generate_dag_batch, get_dag_hash
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Generate sample DAGs
dags = generate_dag_batch(10, min_nodes=5, max_nodes=15)

for G, h in dags:
    print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}, Hash: {h}")

# %%
# Visualize a sample DAG
G, h = dags[0]
plt.figure(figsize=(10, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', arrows=True)
plt.title(f"Sample DAG (hash: {h})")
plt.show()
