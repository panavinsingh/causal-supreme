# %% [markdown]
# # Statistics Exploration
#
# This notebook explores dataset statistics and validates integrity.

# %%
import json
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np

# %%
def load_jsonl(path):
    samples = []
    with open(path, 'r') as f:
        for line in f:
            samples.append(json.loads(line))
    return samples

# Load splits (adjust paths as needed)
# train = load_jsonl('../data/splits/train.jsonl')
# test = load_jsonl('../data/splits/test.jsonl')

# %%
# Rung distribution
# rung_counts = defaultdict(int)
# for s in test:
#     rung_counts[s['rung']] += 1
# print("Rung distribution:", dict(rung_counts))

# %%
# Variable distributions
# var_values = defaultdict(list)
# for s in test[:500]:
#     x = s['query']['X_factual']
#     for i, v in enumerate(x):
#         var_values[i].append(v)
#
# fig, axes = plt.subplots(3, 5, figsize=(15, 9))
# for i, ax in enumerate(axes.flat):
#     if i in var_values:
#         ax.hist(var_values[i], bins=30, alpha=0.7)
#         ax.set_title(f'Var {i}')
# plt.tight_layout()
# plt.show()
